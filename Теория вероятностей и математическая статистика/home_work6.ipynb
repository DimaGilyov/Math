# %%
import numpy as np
import pandas as pd
import scipy.stats as st

# %% [markdown]
# Мат ожидание

# %%
x = [-1, 0, 1, 2]
p = [0.1, 0.2, 0.3, 0.4]

# %%
s = []
for p_i, x_i in zip(p, x):
    s.append(p_i * x_i)
sum(s)
# Out:
# 1.0

# %% [markdown]
# Найти вероятность что попадем в интервал 12 и 14

# %%
m = 10
d = 2
z_12 = (12 - m) / d 
z_14 = (14 - m) / d 
print(z_12, z_14)
# Out:
# 1.0 2.0

# %%
p1 = 0.15866
p2 = 0.02275
z = p1 - p2
z
# Out:
# 0.13591

# %% [markdown]
# Полная Вероятность что будетвсе ок

# %%
p = 0.75 * 0.60 + 0.25*0.80
p
# Out:
# 0.6499999999999999

# %% [markdown]
# Пирсон

# %%
x = [-0.22, 1.11, -0.16, -0.32, -1.01, -1.22, 0.92, -0.26, 0.62, -0.47]
y = [0.78, 0.8, 1.03, 1.83, 0.89, -0.31, 1.19, 1.82, 1.19, 1.35]
corrcoef_2 = np.corrcoef(x, y)
corrcoef_2
# Out:
# array([[1.        , 0.29319918],
#        [0.29319918, 1.        ]])

# %% [markdown]
# Расчет P-val

# %%
p_value = 2 * min(p1, p2)
p_value
# Out:
# 0.0455
